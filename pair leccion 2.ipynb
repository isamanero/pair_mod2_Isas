# %%
import json
import pandas as pd

# %%
df_games = pd.read_csv("archivos/videogames.csv")

# %%
df_games.head()
# Out:
#    Unnamed: 0                        name  \
# 0           0                  Spider-Man
# 1           1      Red Dead Redemption II
# 2           2          Grand Theft Auto V
# 3           3                  God of War
# 4           4  Uncharted 4: A Thief's End
#
#                                                  url    year certificate  \
# 0  https://www.imdb.com/title/tt5807780/?ref_=adv...  2018.0           T
# 1  https://www.imdb.com/title/tt6161168/?ref_=adv...  2018.0           M
# 2  https://www.imdb.com/title/tt2103188/?ref_=adv...  2013.0           M
# 3  https://www.imdb.com/title/tt5838588/?ref_=adv...  2018.0           M
# 4  https://www.imdb.com/title/tt3334704/?ref_=adv...  2016.0           T
#
#    rating   votes                                               plot  Action  \
# 0     9.2  20,759  When a new villain threatens New York City, Pe...    True
# 1     9.7  35,703  Amidst the decline of the Wild West at the tur...    True
# ...

# %%
df_games = pd.read_csv("archivos/videogames.csv", index_col=0)

# %%
df_games.head()
# Out:
#                          name  \
# 0                  Spider-Man
# 1      Red Dead Redemption II
# 2          Grand Theft Auto V
# 3                  God of War
# 4  Uncharted 4: A Thief's End
#
#                                                  url    year certificate  \
# 0  https://www.imdb.com/title/tt5807780/?ref_=adv...  2018.0           T
# 1  https://www.imdb.com/title/tt6161168/?ref_=adv...  2018.0           M
# 2  https://www.imdb.com/title/tt2103188/?ref_=adv...  2013.0           M
# 3  https://www.imdb.com/title/tt5838588/?ref_=adv...  2018.0           M
# 4  https://www.imdb.com/title/tt3334704/?ref_=adv...  2016.0           T
#
#    rating   votes                                               plot  Action  \
# 0     9.2  20,759  When a new villain threatens New York City, Pe...    True
# 1     9.7  35,703  Amidst the decline of the Wild West at the tur...    True
# 2     9.5  59,986  Three very different criminals team up for a s...    True
# ...

# %%
df_games.to_excel("videogames.xlsx")

# %%
df_games = pd.read_excel("videogames.xlsx", index_col=0)

# %%
df_games.head()
# Out:
#                          name  \
# 0                  Spider-Man
# 1      Red Dead Redemption II
# 2          Grand Theft Auto V
# 3                  God of War
# 4  Uncharted 4: A Thief's End
#
#                                                  url    year certificate  \
# 0  https://www.imdb.com/title/tt5807780/?ref_=adv...  2018.0           T
# 1  https://www.imdb.com/title/tt6161168/?ref_=adv...  2018.0           M
# 2  https://www.imdb.com/title/tt2103188/?ref_=adv...  2013.0           M
# 3  https://www.imdb.com/title/tt5838588/?ref_=adv...  2018.0           M
# 4  https://www.imdb.com/title/tt3334704/?ref_=adv...  2016.0           T
#
#    rating   votes                                               plot  Action  \
# 0     9.2  20,759  When a new villain threatens New York City, Pe...    True
# 1     9.7  35,703  Amidst the decline of the Wild West at the tur...    True
# 2     9.5  59,986  Three very different criminals team up for a s...    True
# ...

# %%
df_games.to_csv("archivos/Files/videogames.csv")

# %%
df_personal =pd.read_json("archivos/personal.json")

# %%
df_personal.to_json("archivos/Files/personal.json")

# %%
with open("archivos/Files/personal.json", "r") as fichero:
    personal = json.load(fichero)

# %%
for person in personal["workers"]:
    print(person)
# Out:
# 0
# 1
# 2
# 3

# %%
personal
# Out:
# {'workers': {'0': {'nombre': 'Ana',
#    'edad': 34,
#    'experiencia': 5,
#    'nivel': 'Senior',
#    'salario': 50000,
#    'mascota': 'gatos'},
#   '1': {'nombre': 'Eva',
#    'edad': 37,
#    'experiencia': 2,
#    'nivel': 'Mid',
#    'salario': 35000},
#   '2': {'nombre': 'Marta',
#    'edad': 27,
#    'experiencia': 1,
#    'nivel': 'Junior',
#    'salario': 25000},
#   '3': {'nombre': 'Paula',
#    'edad': 30,
#    'experiencia': 3,
#    'nivel': 'Mid',
#    'salario': 35000}}}

# %%
df_tabla = pd.json_normalize(personal)

# %%
df_tabla
# Out:
#   workers.0.nombre  workers.0.edad  workers.0.experiencia workers.0.nivel  \
# 0              Ana              34                      5          Senior
#
#    workers.0.salario workers.0.mascota workers.1.nombre  workers.1.edad  \
# 0              50000             gatos              Eva              37
#
#    workers.1.experiencia workers.1.nivel  ...  workers.2.nombre  \
# 0                      2             Mid  ...             Marta
#
#   workers.2.edad  workers.2.experiencia  workers.2.nivel workers.2.salario  \
# 0             27                      1           Junior             25000
#
#    workers.3.nombre workers.3.edad  workers.3.experiencia  workers.3.nivel  \
# 0             Paula             30                      3              Mid
#
#   workers.3.salario
# 0             35000
#
# [1 rows x 21 columns]

# %%
for person in personal["workers"]:
    print(person)
# Out:
# 0
# 1
# 2
# 3

# %%
personal
# Out:
# {'workers': {'0': {'nombre': 'Ana',
#    'edad': 34,
#    'experiencia': 5,
#    'nivel': 'Senior',
#    'salario': 50000,
#    'mascota': 'gatos'},
#   '1': {'nombre': 'Eva',
#    'edad': 37,
#    'experiencia': 2,
#    'nivel': 'Mid',
#    'salario': 35000},
#   '2': {'nombre': 'Marta',
#    'edad': 27,
#    'experiencia': 1,
#    'nivel': 'Junior',
#    'salario': 25000},
#   '3': {'nombre': 'Paula',
#    'edad': 30,
#    'experiencia': 3,
#    'nivel': 'Mid',
#    'salario': 35000}}}

# %%
df_tabla = pd.json_normalize(personal["workers"])
print(df_tabla)
# Out:
#   0.nombre  0.edad  0.experiencia 0.nivel  0.salario 0.mascota 1.nombre  \
# 0      Ana      34              5  Senior      50000     gatos      Eva
#
#    1.edad  1.experiencia 1.nivel  ...  2.nombre 2.edad  2.experiencia  \
# 0      37              2     Mid  ...     Marta     27              1
#
#    2.nivel 2.salario  3.nombre 3.edad  3.experiencia  3.nivel 3.salario
# 0   Junior     25000     Paula     30              3      Mid     35000
#
# [1 rows x 21 columns]

# %%
"""with open("files/personal2.json", "w") as f:
    json.dump('personal', f)"""
